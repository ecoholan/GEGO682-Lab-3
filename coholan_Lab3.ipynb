# %% [markdown]
# # Eric Coholan
# # 4/12/2020
# # GEOG 682 Lab 3

# %%
import rasterio
from rasterio import plot
from rasterio.merge import merge
import matplotlib.pyplot as plt

# %%
satdat1 = rasterio.open("image1.tif")
satdat2 = rasterio.open("image2.tif")

# %%
plot.show(satdat1, cmap='terrain')

# %%
plot.show(satdat2, cmap='terrain')

# %%
satdat1.crs
# Out:
# CRS.from_epsg(32618)

# %%
satdat2.crs
# Out:
# CRS.from_epsg(32618)

# %% [markdown]
# WGS 84 / UTM zone 18N

# %%
fig, (axr, axg, axb, axn) = plt.subplots(1,4, figsize=(20,5))
plot.show((satdat1, 4), ax=axn, cmap='RdPu', title='NIR channel')
plot.show((satdat1, 3), ax=axr, cmap='Reds', title='red channel')
plot.show((satdat1, 2), ax=axg, cmap='Greens', title='green channel')
plot.show((satdat1, 1), ax=axb, cmap='Blues', title='blue channel')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-79e574f29ea8> in <module>
#       1 fig, (axr, axg, axb, axn) = plt.subplots(1,4, figsize=(20,5))
# ----> 2 plot.show((satdat1, 4), ax=axn, cmap='RdPu', title='NIR channel')
#       3 plot.show((satdat1, 3), ax=axr, cmap='Reds', title='red channel')
#       4 plot.show((satdat1, 2), ax=axg, cmap='Greens', title='green channel')
#       5 plot.show((satdat1, 1), ax=axb, cmap='Blues', title='blue channel')
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/rasterio/plot.py in show(source, with_bounds, contour, contour_label_kws, ax, title, transform, adjust, **kwargs)
#      81
#      82     if isinstance(source, tuple):
# ---> 83         arr = source[0].read(source[1])
#      84         if len(arr.shape) >= 3:
#      85             arr = reshape_as_image(arr)
#
# rasterio/_io.pyx in rasterio._io.DatasetReaderBase.read()
#
# IndexError: band index 4 out of range (not in (1, 2, 3))

# %%
files_to_mosaic = [satdat1, satdat2]

# %%
mosaic, out_trans = merge(files_to_mosaic)

# %%
plot.show(mosaic, cmap = 'terrain')
